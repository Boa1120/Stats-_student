# %% [markdown]
# <a href="https://colab.research.google.com/github/Boa1120/Stats-_student/blob/main/Pablo_Gamboa__Lab_6_Cereal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import urllib.request

# %% [markdown]
# Comment: The code below is the data set for the information of each cereal category.

# %%
urllib.request.urlretrieve('https://raw.githubusercontent.com/williamedwardhahn/Probability_Statistics/main/cereal_data.csv','cereal_data.csv')
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7fe78326a310>)

# %%
cereal_data = pd.read_csv('cereal_data.csv')

# %% [markdown]
# Name: Name of cereal
#
# mfr: Manufacturer of cereal
#
#     A = American Home Food Products
#
#     G = General Mills
#
#     K = Kelloggs
#
#     N = Nabisco
#
#     P = Post
#
#     Q = Quaker Oats
#
#     R = Ralston Purina
#
# type:
#
#     cold
#
#     hot
#
# calories: calories per serving
#
# protein: grams of protein
#
# fat: grams of fat
#
# sodium: milligrams of sodium
#
# fiber: grams of dietary fiber
#
# carbo: grams of complex carbohydrates
#
# sugars: grams of sugars
#
# potass: milligrams of potassium
#
# vitamins: vitamins and minerals - 0, 25, or 100,
# indicating the typical percentage of FDA recommended
#
# shelf: display shelf (1, 2, or 3, counting from the floor)
#
# weight: weight in ounces of one serving
#
# cups: number of cups in one serving
#
# rating: a rating of the cereals

# %% [markdown]
# Comment: Here is the display for the cereal information with each row being a different brand.

# %%
cereal_data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# Comment: The code below is the sum of the mean of the column for the sugars data set for each brand.

# %%
cereal_data["sugars"].mean()
# Out:
# 6.922077922077922

# %% [markdown]
# Comment: The code below is used to calculate the mean of both the calories and sugars columns.

# %%
cereal_data[["calories", "sugars"]].mean()
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %% [markdown]
# Comment: Below is the average (mean) value for each data (column) for each brand (row)

# %%
cereal_data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %% [markdown]
# Comment: The data displayed below is the data for sugars and calories of each brand of cereal.

# %%
cereal_data[["calories", "sugars"]]
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %% [markdown]
# Comment: The following codes below are for graphing each category displayed in the code for all 77 brands.

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["carbo"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["vitamins"]],'.')

# %%
X = cereal_data[["sugars"]]
Y = cereal_data[["calories"]]

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()

# %%
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)

# %% [markdown]
# Comment: The code below is for the linear regression or the line of best fit.

# %%
plt.plot(X, Y,'.')
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,50)

# %%
noise = 10 * np.random.randn(50,)

# %%
y = 3 * x + 7 + noise

# %% [markdown]
# Comment: The following graphs below are plots geberating random data values from the data set.

# %%
plt.plot(x,y,'.');

# %%
m_guess = 1
b_guess = 1

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 5
b_guess = 15

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 3
b_guess = 7

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
loss = np.sum((y_guess - y)**2)

# %%
loss
# Out:
# 3643.127408198577

# %% [markdown]
# Comment: Here is where the code will guess the output of the model from out of all data provided using linear regression.

# %%
for m_guess in np.linspace(-10,10,10):
    for b_guess in np.linspace(-10,10,10):
        
        y_guess = m_guess * x + b_guess

        plt.plot(x,y_guess,'r.');
        plt.plot(x,y,'g.');
        plt.show()

        loss = np.sum((y_guess - y)**2)

        print(loss,m_guess,b_guess)
# Out:
# 406398.272615266 -10.0 -10.0
# 388675.53449595213 -10.0 -7.777777777777778
# 371446.6235371321 -10.0 -5.555555555555555
# 354711.539738806 -10.0 -3.333333333333333
# 338470.28310097364 -10.0 -1.1111111111111107
# 322722.85362363514 -10.0 1.1111111111111107
# 307469.25130679045 -10.0 3.333333333333334
# 292709.4761504395 -10.0 5.555555555555557
# 278443.52815458254 -10.0 7.777777777777779
# 264671.4073192193 -10.0 10.0
# 299366.02129054023 -7.777777777777778 -10.0
# 284112.4189736955 -7.777777777777778 -7.777777777777778
# 269352.6438173447 -7.777777777777778 -5.555555555555555
# 255086.69582148766 -7.777777777777778 -3.333333333333333
# 241314.57498612444 -7.777777777777778 -1.1111111111111107
# 228036.28131125504 -7.777777777777778 1.1111111111111107
# 215251.81479687954 -7.777777777777778 3.333333333333334
# 202961.1754429978 -7.777777777777778 5.555555555555557
# 191164.36324960986 -7.777777777777778 7.777777777777779
# 179861.3782167158 -7.777777777777778 10.0
# ...

# %% [markdown]
# Comment: The code below is for the line of best fit for the best guessed loss in the arranged data set.

# %%
best_loss = 100000
best_m = 0
best_b = 0 

for m_guess in np.linspace(-10,10,20):
    for b_guess in np.linspace(-10,10,20):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess 

            plt.plot(x,y_guess,'r.');
            plt.plot(x,y,'g.');
            plt.show()

            print(loss,m_guess,b_guess)
# Out:
# 98247.41051886437 -4.736842105263158 7.894736842105264
# 94444.61151436332 -4.736842105263158 8.94736842105263
# 90752.61583396197 -4.736842105263158 10.0
# 87652.17878422332 -3.6842105263157894 3.6842105263157894
# 83960.183103822 -3.6842105263157894 4.7368421052631575
# 80378.99074752037 -3.6842105263157894 5.789473684210526
# 76908.60171531845 -3.6842105263157894 6.842105263157894
# 73549.01600721627 -3.6842105263157894 7.894736842105264
# 70300.2336232138 -3.6842105263157894 8.94736842105263
# 67162.25456331107 -3.6842105263157894 10.0
# 64468.85013271428 -2.6315789473684212 3.6842105263157894
# 61330.87107281155 -2.6315789473684212 4.7368421052631575
# 58303.69533700853 -2.6315789473684212 5.789473684210526
# 55387.32292530526 -2.6315789473684212 6.842105263157894
# 52581.7538377017 -2.6315789473684212 7.894736842105264
# 49886.98807419786 -2.6315789473684212 8.94736842105263
# 47303.02563479373 -2.6315789473684212 10.0
# 45016.65382333878 -1.578947368421053 3.6842105263157894
# ...
